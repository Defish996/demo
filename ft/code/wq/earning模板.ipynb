# %%
from main import *
s = login()
# Out:
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'

# %%
# df = get_datafields(s, dataset_id = 'analyst10', region='USA', universe='ILLIQUID_MINVOL1M', delay=1)
# print(df)
# print(df[df['type'] == "MATRIX"]["id"].tolist())
# pc_fields = process_datafields(df, "matrix")
# print(pc_fields)


# # %%
df = get_datafields(s, dataset_id='earnings7', region='USA', universe='ILLIQUID_MINVOL1M', delay=1)
print(df[df['type'] == "VECTOR"]["id"].tolist())
print(len(df[df['type'] == "VECTOR"]["id"].tolist()))
ve_fields = process_datafields(df, "vector")
print(ve_fields)
print(len(ve_fields))
# Out:
# ['ern7_co_spe', 'ern7_dsu_spe', 'ern7_spe']
# 3
# ['winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4)', 'winsorize(ts_backfill(vec_sum(ern7_co_spe), 120), std=4)', 'winsorize(ts_backfill(vec_max(ern7_co_spe), 120), std=4)', 'winsorize(ts_backfill(vec_min(ern7_co_spe), 120), std=4)', 'winsorize(ts_backfill(vec_avg(ern7_dsu_spe), 120), std=4)', 'winsorize(ts_backfill(vec_sum(ern7_dsu_spe), 120), std=4)', 'winsorize(ts_backfill(vec_max(ern7_dsu_spe), 120), std=4)', 'winsorize(ts_backfill(vec_min(ern7_dsu_spe), 120), std=4)', 'winsorize(ts_backfill(vec_avg(ern7_spe), 120), std=4)', 'winsorize(ts_backfill(vec_sum(ern7_spe), 120), std=4)', 'winsorize(ts_backfill(vec_max(ern7_spe), 120), std=4)', 'winsorize(ts_backfill(vec_min(ern7_spe), 120), std=4)']
# 12

# %%
# 定义可能的 decay 参数
op = 'ts_rank'
first_list = []
for field in ve_fields:
    alpha = ts_factory(op, field)
    first_list.append(alpha)

op_list = ["ts_median","ts_sum", "ts_max", "ts_zscore", "ts_arg_max","ts_std_dev","ts_product","ts_delta","ts_delay","ts_count_nans","ts_av_diff","ts_arg_min","ts_arg_max"]
second_list = []
for a_list in first_list:
    for alpha in a_list:
        for oper in op_list:
            tmp = ts_factory(oper, alpha)
            second_list.append(tmp)

print(second_list[:10])
print(len(second_list))
# Out:
# [['ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], ['ts_count_nans(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4),  ...
# 780

# %%
init_decay = 6
fo_alpha_list = []
for alpha in second_list:
    fo_alpha_list.append((alpha, init_decay))
print(fo_alpha_list[:10])
print(len(second_list))

pools = load_task_pool(fo_alpha_list, 10, 9)
print(pools[0])

multi_simulate(pools, "SUBINDUSTRY", "USA", "ILLIQUID_MINVOL1M", 0)
# Out:
# [(['ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_count_nans(ts_rank(winsorize(ts ...
# 780
# [[(['ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_median(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_sum(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_zscore(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_arg_max(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_std_dev(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_product(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delta(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 5)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 22)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 66)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 120)', 'ts_delay(ts_rank(winsorize(ts_backfill(vec_avg(ern7_co_spe), 120), std=4), 5), 240)'], 6), (['ts_count_nans(ts_rank(winsorize(t ...
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 0 task 8 post done
# pool 0 task 8 simulate done
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
# pool 1 task 8 post done
# pool 1 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 2 task 8 post done
# pool 2 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
# pool 3 task 8 post done
# pool 3 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
# pool 4 task 8 post done
# pool 4 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
# pool 5 task 8 post done
# pool 5 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 6 task 8 post done
# pool 6 task 8 simulate done
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
# pool 7 task 8 post done
# pool 7 task 8 simulate done
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{"user":{"id":"YW10763"},"token":{"expiry":21600.0},"permissions":["BEFORE_AND_AFTER_PERFORMANCE_V2","BRAIN_LABS","BRAIN_LABS_JUPYTER_LAB","CONSULTANT","MULTI_SIMULATION","PROD_ALPHAS","REFERRAL","SUPER_ALPHA","VISUALIZATION","WORKDAY"]}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# b'{\n  "message":"API rate limit exceeded"\n}'
#  loc key error
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\code\wq\main.py:514, in multi_simulate(alpha_pools, neut, region, universe, start)
#     513 simulation_response = s.post('https://api.worldquantbrain.com/simulations', json=sim_data_list)
# --> 514 simulation_progress_url = simulation_response.headers['Location']
#     515 progress_urls.append(simulation_progress_url)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\structures.py:52, in CaseInsensitiveDict.__getitem__(self, key)
#      51 def __getitem__(self, key):
# ---> 52     return self._store[key.lower()][1]
#
# KeyError: 'location'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 11
#       8 pools = load_task_pool(fo_alpha_list, 10, 9)
#       9 print(pools[0])
# ---> 11 multi_simulate(pools, "SUBINDUSTRY", "USA", "ILLIQUID_MINVOL1M", 0)
#
# File c:\code\wq\main.py:519, in multi_simulate(alpha_pools, neut, region, universe, start)
#     517         print(" loc key error")# 参数设置有问题
#     518         # sleep(600)
# --> 519         s = login()
#     521 print("pool %d task %d post done"%(x,y))
#     523 for j, progress in enumerate(progress_urls):
#
# File c:\code\wq\main.py:382, in login()
#     379 s.auth = (username, password)
#     381 # Send a POST request to the /authentication API
# --> 382 response = s.post('https://api.worldquantbrain.com/authentication')
#     383 print(response.content)
#     384 return s
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)    634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:773, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     771 if self.proxy is not None and http_tunnel_required and conn.is_closed:
#     772     try:
# --> 773         self._prepare_proxy(conn)
#     774     except (BaseSSLError, OSError, SocketTimeout) as e:
#     775         self._raise_timeout(
#     776             err=e, url=self.proxy.url, timeout_value=conn.timeout
#     777         )
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1034     tunnel_scheme = "http"
#    1036 conn.set_tunnel(
#    1037     scheme=tunnel_scheme,
#    1038     host=self._tunnel_host,
#    1039     port=self.port,
#    1040     headers=self.proxy_headers,
#    1041 )
# -> 1042 conn.connect()
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     787     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     788     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791         sock=sock,
#     792         cert_reqs=self.cert_reqs,
#     793         ssl_version=self.ssl_version,
#     794         ssl_minimum_version=self.ssl_minimum_version,
#     795         ssl_maximum_version=self.ssl_maximum_version,
#     796         ca_certs=self.ca_certs,
#     797         ca_cert_dir=self.ca_cert_dir,
#     798         ca_cert_data=self.ca_cert_data,
#     799         cert_file=self.cert_file,
#     800         key_file=self.key_file,
#     801         key_password=self.key_password,
#     802         server_hostname=server_hostname_rm_dot,
#     803         ssl_context=self.ssl_context,
#     804         tls_in_tls=tls_in_tls,
#     805         assert_hostname=self.assert_hostname,
#     806         assert_fingerprint=self.assert_fingerprint,
#     807     )
#     808     self.sock = sock_and_verified.socket
#     810 # If an error occurs during connection/handshake we may need to release
#     811 # our lock so another connection can probe the origin.
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     966     if is_ipaddress(normalized):
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#     983     if assert_fingerprint:
#
# File c:\Users\1\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456 if ca_certs or ca_cert_dir or ca_cert_data:
#     457     try:
# --> 458         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     459     except OSError as e:
#     460         raise SSLError(e) from e
#
# KeyboardInterrupt:
